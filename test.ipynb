# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Test").getOrCreate()

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database credentials
hostname = "localhost"
port = "5434"
database = "airflow"
username = "airflow"
password = "airflow"

# Create a connection string
connection_string = f"postgresql+psycopg2://{username}:{password}@{hostname}:{port}/{database}"

# Create a SQLAlchemy engine
engine = create_engine(connection_string)

# Read the table into a DataFrame
table_name = "ohitv_request"
df = pd.read_sql_table(table_name, con=engine)

df
# Out:
#               id                          title  \
# 0     post-27536               Lốc Xoáy Tử Thần
# 1     post-27536               Lốc Xoáy Tử Thần
# 2     post-27536               Lốc Xoáy Tử Thần
# 3     post-27536               Lốc Xoáy Tử Thần
# 4     post-35938          Đẹp Trai…Thấy Sai Sai
# ...          ...                            ...
# 1493   post-3440  Cô Nàng Mạnh Mẽ Gang Nam Soon
# 1494   post-3440  Cô Nàng Mạnh Mẽ Gang Nam Soon
# 1495   post-3440  Cô Nàng Mạnh Mẽ Gang Nam Soon
# 1496  post-13352                     Hoa Khê Ký
# 1497  post-13352                     Hoa Khê Ký
#
#                                                   links published_date  \
# 0           https://ohitv.net/phim-le/loc-xoay-tu-than/     2024-07-10
# 1           https://ohitv.net/phim-le/loc-xoay-tu-than/     2024-07-10
# 2           https://ohitv.net/phim-le/loc-xoay-tu-than/     2024-07-10
# 3           https://ohitv.net/phim-le/loc-xoay-tu-than/     2024-07-10
# 4      https://ohitv.net/phim-le/dep-trai-thay-sai-sai/     2024-06-26
# ...                                                 ...            ...
# 1493  https://ohitv.net/phim-bo/co-nang-manh-me-gang...     2023-10-07
# 1494  https://ohitv.net/phim-bo/co-nang-manh-me-gang...     2023-10-07
# 1495  https://ohitv.net/phim-bo/co-nang-manh-me-gang...     2023-10-07
# 1496              https://ohitv.net/phim-bo/hoa-khe-ky/     2023-09-16
# 1497              https://ohitv.net/phim-bo/hoa-khe-ky/     2023-09-16
#
#       rating quality             genre  \
# 0      7.100   1080p    Phim Chiếu Rạp
# 1      7.100   1080p      Phim Gây Cấn
# 2      7.100   1080p    Phim Hành Động
# 3      7.100   1080p    Phim Phiêu Lưu
# 4      6.900   1080p    Phim Chiếu Rạp
# ...      ...     ...               ...
# 1493   8.286           Phim Chính Kịch
# 1494   8.286                  Phim Hài
# 1495   8.286          Sci-Fi & Fantasy
# 1496   0.000                  Phim Hài
# 1497   0.000          Sci-Fi & Fantasy
#
#                                       short_description date_crawl
# 0     Kate Cooper, một nhà săn bão từng trải qua cơn... 2024-08-19
# 1     Kate Cooper, một nhà săn bão từng trải qua cơn... 2024-08-19
# 2     Kate Cooper, một nhà săn bão từng trải qua cơn... 2024-08-19
# 3     Kate Cooper, một nhà săn bão từng trải qua cơn... 2024-08-19
# 4     “Đẹp Trai…Thấy Sai Sai” là một bộ phim hài tìn... 2024-08-19
# ...                                                 ...        ...
# 1493  “Cô Nàng Mạnh Mẽ Gang Nam Soon” là một bộ phim... 2024-08-19
# 1494  “Cô Nàng Mạnh Mẽ Gang Nam Soon” là một bộ phim... 2024-08-19
# 1495  “Cô Nàng Mạnh Mẽ Gang Nam Soon” là một bộ phim... 2024-08-19
# 1496  “Hoa Khê Ký” (2023) là một bộ phim cổ trang ng... 2024-08-19
# 1497  “Hoa Khê Ký” (2023) là một bộ phim cổ trang ng... 2024-08-19
#
# [1498 rows x 9 columns]
